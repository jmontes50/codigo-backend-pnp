# %%
import pandas as pd

# %%
df = pd.read_csv('Info_csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-f3037715b5b7> in <module>
# ----> 1 df = pd.read_csv('Info_csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
# ...

# %%
df = pd.read_csv('Info_pais.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-843316dfc521> in <module>
# ----> 1 df = pd.read_csv('Info_pais.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
# ...

# %%
df = pd.read_csv('Info_pais.csv', encoding = "ISO-8859-1", delimiter=";")

# %%
df
# Out:
#                  País   Poblacion  Renta per capita Esperanza de vida
# 0       United States   325084756             59939              78,9
# 1               China  1421021791              8612              76,7
# 2               Japan   127502725             38214              84,5
# 3             Germany    82658409             44680              81,2
# 4               India  1338676785              1980              69,4
# ..                ...         ...               ...               ...
# 163             Samoa      195352              4305              73,2
# 164             Tonga      101998              4193              70,8
# 165             Palau       17808             16275              73,7
# 166  Marshall Islands       58058              3517              73,9
# 167          Kiribati      114158              1626              68,1
#
# [168 rows x 4 columns]

# %%
df.head()
# Out:
#             País   Poblacion  Renta per capita Esperanza de vida
# 0  United States   325084756             59939              78,9
# 1          China  1421021791              8612              76,7
# 2          Japan   127502725             38214              84,5
# 3        Germany    82658409             44680              81,2
# 4          India  1338676785              1980              69,4

# %%
df.head(30)
# Out:
#                     País   Poblacion  Renta per capita Esperanza de vida
# 0          United States   325084756             59939              78,9
# 1                  China  1421021791              8612              76,7
# 2                  Japan   127502725             38214              84,5
# 3                Germany    82658409             44680              81,2
# 4                  India  1338676785              1980              69,4
# 5         United Kingdom    66727461             39532              81,2
# 6                 France    64842509             39827              82,5
# 7                 Brazil   207833823              9881              75,7
# 8                  Italy    60673701             32038              83,6
# 9                 Canada    36732095             44841              82,3
# 10                Russia   145530082             10846              72,4
# 11           South Korea    51096415             29958              82,8
# ...

# %%
df2 = pd.read_csv('library.csv')

# %%
df2
# Out:
#       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %%
df2.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
to_drop = [
    'Edition Statement',
    'Corporate Author',
    'Corporate Contributors',
    'Former owner',
    'Engraver'
]

df2.drop(to_drop, inplace=True, axis=1)

# %%
df2.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors Issuance type  \
# ...

# %%
df2['Identifier'].is_unique
# Out:
# True

# %%
df2 = df2.set_index('Identifier')

# %%
df2.loc[206]
# Out:
# Place of Publication                                               London
# Date of Publication                                           1879 [1878]
# Publisher                                                S. Tinsley & Co.
# Title                                   Walter Forbes. [A novel.] By A. A
# Author                                                              A. A.
# Contributors                                              FORBES, Walter.
# Issuance type                                                 monographic
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Shelfmarks                              British Library HMNTS 12641.b.30.
# Name: 206, dtype: object

# %%
df2.loc[480]
# Out:
# Place of Publication                                               London
# Date of Publication                                                  1857
# Publisher                                            Wertheim & Macintosh
# Title                   [The World in which I live, and my place in it...
# Author                                                          A., E. S.
# Contributors                                          BROOME, John Henry.
# Issuance type                                                 monographic
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Shelfmarks                               British Library HMNTS 9007.d.28.
# Name: 480, dtype: object

# %%
df2.to_csv('libreria_filtrada.csv')

# %%
df3 = pd.read_csv('libreria_filtrada.csv');

# %%
df3
# Out:
#       Identifier      Place of Publication Date of Publication  \
# 0            206                    London         1879 [1878]
# 1            216  London; Virtue & Yorston                1868
# 2            218                    London                1869
# 3            472                    London                1851
# 4            480                    London                1857
# ...          ...                       ...                 ...
# 8282     4158088                    London                1838
# 8283     4158128                     Derby            1831, 32
# 8284     4159563                    London           [1806]-22
# 8285     4159587       Newcastle upon Tyne                1834
# 8286     4160339                    London             1834-43
#
#                     Publisher  \
# 0            S. Tinsley & Co.
# 1                Virtue & Co.
# 2       Bradbury, Evans & Co.
# 3               James Darling
# 4        Wertheim & Macintosh
# ...

# %%
df2.loc[206]
# Out:
# Place of Publication                                               London
# Date of Publication                                           1879 [1878]
# Publisher                                                S. Tinsley & Co.
# Title                                   Walter Forbes. [A novel.] By A. A
# Author                                                              A. A.
# Contributors                                              FORBES, Walter.
# Issuance type                                                 monographic
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Shelfmarks                              British Library HMNTS 12641.b.30.
# Name: 206, dtype: object

# %%
df2.get_type_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-2dfeda6187fb> in <module>
# ----> 1 df2.get_type_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_type_counts'

# %%
df2.get_dtype_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-9b5d0aebc99d> in <module>
# ----> 1 df2.get_dtype_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtype_counts'

# %%
df2.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-3e685d01241e> in <module>
# ----> 1 df2.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df2.types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-40c4d32bc9c2> in <module>
# ----> 1 df2.types
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
df2.dtypes
# Out:
# Place of Publication    object
# Date of Publication     object
# Publisher               object
# Title                   object
# Author                  object
# Contributors            object
# Issuance type           object
# Flickr URL              object
# Shelfmarks              object
# dtype: object

# %%
df2.loc[1905:, 'Date of Publication'].head(10)
# Out:
# Identifier
# 1905           1888
# 1929    1839, 38-54
# 2836           1897
# 2854           1865
# 2956        1860-63
# 2957           1873
# 3017           1866
# 3131           1899
# 4598           1814
# 4884           1820
# Name: Date of Publication, dtype: object

# %%
extr = df2['Date of Publication'].str.extract(r'^(d{4})', expand=False)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-29-24d4a01763c8> in <module>
# ----> 1 extr = df2['Date of Publication'].str.extract(r'^d{4})', expand=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings.py in wrapper(self, *args, **kwargs)
#    1999                 )
#    2000                 raise TypeError(msg)
# -> 2001             return func(self, *args, **kwargs)
#    2002
#    2003         wrapper.__name__ = func_name
#
# ~\anaconda3\lib\site-packages\pandas\core\strings.py in extract(self, pat, flags, expand)
#    3117     @forbid_nonstring_types(["bytes"])
#    3118     def extract(self, pat, flags=0, expand=True):
# -> 3119         return str_extract(self, pat, flags=flags, expand=expand)
#    3120
#    3121     @copy(str_extractall)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings.py in str_extract(arr, pat, flags, expand)
# ...

# %%
extr = df2['Date of Publication'].str.extract(r'^(d{4})', expand=False)

# %%
extr.head()
# Out:
# Identifier
# 206    NaN
# 216    NaN
# 218    NaN
# 472    NaN
# 480    NaN
# Name: Date of Publication, dtype: object

# %%
extr = df2['Date of Publication'].str.extract(r'^(\d{4})', expand=False)

# %%
extr.head()
# Out:
# Identifier
# 206    1879
# 216    1868
# 218    1869
# 472    1851
# 480    1857
# Name: Date of Publication, dtype: object

# %%
df2['Date of Publication'] = pd.to_numeric(extr)

# %%
df2['Date of Publication'].dtype
# Out:
# dtype('float64')

# %%
df2.head(10)
# Out:
#                            Place of Publication  Date of Publication  \
# Identifier
# 206                                      London               1879.0
# 216                    London; Virtue & Yorston               1868.0
# 218                                      London               1869.0
# 472                                      London               1851.0
# 480                                      London               1857.0
# 481                                      London               1875.0
# 519                                      London               1872.0
# 667         pp. 40. G. Bryan & Co: Oxford, 1898                  NaN
# 874                                     London]               1676.0
# 1143                                     London               1679.0
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# ...

# %%
import numpy as np

# %%
df2['Place of Publication'].head(10)
# Out:
# Identifier
# 206                                  London
# 216                London; Virtue & Yorston
# 218                                  London
# 472                                  London
# 480                                  London
# 481                                  London
# 519                                  London
# 667     pp. 40. G. Bryan & Co: Oxford, 1898
# 874                                 London]
# 1143                                 London
# Name: Place of Publication, dtype: object

# %%
df2.loc[4157862]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 4157862 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-f62085f644a7> in <module>
# ----> 1 df.loc[4157862]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ...

# %%
df2.loc[4157862]
# Out:
# Place of Publication                                  Newcastle-upon-Tyne
# Date of Publication                                                  1867
# Publisher                                                      T. Fordyce
# Title                   Local Records; or, Historical Register of rema...
# Author                      FORDYCE, T. - Printer, of Newcastle-upon-Tyne
# Contributors             SYKES, John - Bookseller, of Newcastle-upon-Tyne
# Issuance type                                                 monographic
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Shelfmarks              British Library HMNTS|British Library HMNTS 01...
# Name: 4157862, dtype: object

# %%
df2.loc[4159587]
# Out:
# Place of Publication                                  Newcastle upon Tyne
# Date of Publication                                                  1834
# Publisher                                                Mackenzie & Dent
# Title                   An historical, topographical and descriptive v...
# Author                                              Mackenzie, E. (Eneas)
# Contributors                                         ROSS, M. - of Durham
# Issuance type                                                 monographic
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Shelfmarks              British Library HMNTS|British Library HMNTS 10...
# Name: 4159587, dtype: object

# %%
pub = df2['Place of Publication']

# %%
london = pub.str.contains('London')

# %%
london[:5]
# Out:
# Identifier
# 206    True
# 216    True
# 218    True
# 472    True
# 480    True
# Name: Place of Publication, dtype: bool

# %%
oxford = pub.str.contains('Oxford')

# %%
oxford[:10]
# Out:
# Identifier
# 206     False
# 216     False
# 218     False
# 472     False
# 480     False
# 481     False
# 519     False
# 667      True
# 874     False
# 1143    False
# Name: Place of Publication, dtype: bool

# %%
df2['Place of Publication'] = np.where(london, 'London' ,np.where(oxford, 'Oxford', pub.str.replace('-',' ')))

# %%
df2['Place of Publication'].head()
# Out:
# Identifier
# 206    London
# 216    London
# 218    London
# 472    London
# 480    London
# Name: Place of Publication, dtype: object

# %%
df2.head()
# Out:
#            Place of Publication  Date of Publication              Publisher  \
# Identifier
# 206                      London               1879.0       S. Tinsley & Co.
# 216                      London               1868.0           Virtue & Co.
# 218                      London               1869.0  Bradbury, Evans & Co.
# 472                      London               1851.0          James Darling
# 480                      London               1857.0   Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 480         [The World in which I live, and my place in it...  A., E. S.
#
# ...
